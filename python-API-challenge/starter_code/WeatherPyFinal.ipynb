# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 623

# %%
new_cities = []
country = []
cloudiness = []
dates = []
humidity = []
max_temp = []
wind_speed = []
lat = []
long = []


count = 0
set_count = 1

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="


api_keys = weather_api_key

# %%
count = 0
set_count = 0

print(query_url)


print("Beginning Data Retrieval ")
print("-----------------------------")
for i, city in enumerate (cities):
    
    try:
        response = requests.get(query_url + city).json()
        country.append(response['sys']['country'])
        cloudiness.append(response['clouds']['all'])
        dates.append(response['dt'])
        humidity.append(response['main']['humidity'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
        lat.append(response['coord']['lat'])
        long.append(response['coord']['lon'])
        new_cities.append(city)
        if count > 50:
            count = 0
            set_count = set_count + 1
        
        if (i % 50 == 0 and i >= 50):
            set_count += 1
            count = 0

        # Create endpoint URL with each city
        city_url = query_url + "&q=" + city
    
        # Log the url, record, and set numbers
        print("Processing Record %s of Set %s | %s" % (count, set_count, city))

        # Add 1 to the record count
        count += 1
      
            
        print(f"Processing Record {count} of Set {set_count} : {city}") 
   
    except(KeyError, IndexError):
        print("City not found. Skipping...")
        pass
   
print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=64576b21ada60b2e33b1a026ac523b26&units=imperial&q=
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0 of Set 0 | barrow
# Processing Record 1 of Set 0 : barrow
# Processing Record 1 of Set 0 | rikitea
# Processing Record 2 of Set 0 : rikitea
# Processing Record 2 of Set 0 | kaitangata
# Processing Record 3 of Set 0 : kaitangata
# Processing Record 3 of Set 0 | punta arenas
# Processing Record 4 of Set 0 : punta arenas
# Processing Record 4 of Set 0 | nacala
# Processing Record 5 of Set 0 : nacala
# City not found. Skipping...
# Processing Record 5 of Set 0 | saint-philippe
# Processing Record 6 of Set 0 : saint-philippe
# Processing Record 6 of Set 0 | hermanus
# Processing Record 7 of Set 0 : hermanus
# Processing Record 7 of Set 0 | puerto escondido
# Processing Record 8 of Set 0 : puerto escondido
# Processing Record 8 of Set 0 | sur
# Processing Record 9 of Set 0 : sur
# Processing Record 9 of Set 0 | butaritari
# Processing Record 10 of Set 0 : butaritari
# Processing Record 10 of Set 0 | lorengau
# Processing Record 11 of Set 0 : lorengau
# Processing Record 11 of Set 0 | yar-sale
# Processing Record 12 of Set 0 : yar-sale
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 12 of Set 0 | cherskiy
# Processing Record 13 of Set 0 : cherskiy
# Processing Record 13 of Set 0 | ust-ishim
# Processing Record 14 of Set 0 : ust-ishim
# Processing Record 14 of Set 0 | juan lacaze
# Processing Record 15 of Set 0 : juan lacaze
# Processing Record 15 of Set 0 | mataura
# Processing Record 16 of Set 0 : mataura
# Processing Record 16 of Set 0 | xuanzhou
# Processing Record 17 of Set 0 : xuanzhou
# Processing Record 17 of Set 0 | ushuaia
# Processing Record 18 of Set 0 : ushuaia
# Processing Record 18 of Set 0 | cape town
# Processing Record 19 of Set 0 : cape town
# Processing Record 19 of Set 0 | guerrero negro
# Processing Record 20 of Set 0 : guerrero negro
# Processing Record 20 of Set 0 | busselton
# Processing Record 21 of Set 0 : busselton
# Processing Record 21 of Set 0 | bethel
# Processing Record 22 of Set 0 : bethel
# Processing Record 22 of Set 0 | vila
# Processing Record 23 of Set 0 : vila
# Processing Record 23 of Set 0 | maubin
# Processing Record 24 of Set 0 : maubin
# Processing Record 24 of Set 0 | bredasdorp
# Processing Record 25 of Set 0 : bredasdorp
# Processing Record 25 of Set 0 | shar
# Processing Record 26 of Set 0 : shar
# Processing Record 26 of Set 0 | teknaf
# Processing Record 27 of Set 0 : teknaf
# Processing Record 27 of Set 0 | carnarvon
# Processing Record 28 of Set 0 : carnarvon
# Processing Record 28 of Set 0 | richards bay
# Processing Record 29 of Set 0 : richards bay
# Processing Record 29 of Set 0 | lompoc
# Processing Record 30 of Set 0 : lompoc
# Processing Record 30 of Set 0 | east london
# Processing Record 31 of Set 0 : east london
# Processing Record 31 of Set 0 | dunedin
# Processing Record 32 of Set 0 : dunedin
# Processing Record 32 of Set 0 | grand gaube
# Processing Record 33 of Set 0 : grand gaube
# Processing Record 33 of Set 0 | hithadhoo
# Processing Record 34 of Set 0 : hithadhoo
# Processing Record 34 of Set 0 | port pirie
# Processing Record 35 of Set 0 : port pirie
# Processing Record 35 of Set 0 | kruisfontein
# Processing Record 36 of Set 0 : kruisfontein
# Processing Record 36 of Set 0 | ilulissat
# Processing Record 37 of Set 0 : ilulissat
# Processing Record 37 of Set 0 | tuktoyaktuk
# Processing Record 38 of Set 0 : tuktoyaktuk
# Processing Record 38 of Set 0 | hasaki
# Processing Record 39 of Set 0 : hasaki
# Processing Record 39 of Set 0 | viedma
# Processing Record 40 of Set 0 : viedma
# Processing Record 40 of Set 0 | bousse
# Processing Record 41 of Set 0 : bousse
# City not found. Skipping...
# Processing Record 41 of Set 0 | arraial do cabo
# Processing Record 42 of Set 0 : arraial do cabo
# Processing Record 42 of Set 0 | malia
# Processing Record 43 of Set 0 : malia
# Processing Record 43 of Set 0 | kawalu
# Processing Record 44 of Set 0 : kawalu
# Processing Record 44 of Set 0 | tommot
# Processing Record 45 of Set 0 : tommot
# Processing Record 45 of Set 0 | saint george
# Processing Record 46 of Set 0 : saint george
# Processing Record 0 of Set 1 | vaini
# Processing Record 1 of Set 1 : vaini
# Processing Record 1 of Set 1 | namatanai
# Processing Record 2 of Set 1 : namatanai
# Processing Record 2 of Set 1 | norman wells
# Processing Record 3 of Set 1 : norman wells
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 : puerto ayora
# Processing Record 4 of Set 1 | hirara
# Processing Record 5 of Set 1 : hirara
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 : jamestown
# Processing Record 6 of Set 1 | samarai
# Processing Record 7 of Set 1 : samarai
# Processing Record 7 of Set 1 | moranbah
# Processing Record 8 of Set 1 : moranbah
# Processing Record 8 of Set 1 | flinders
# Processing Record 9 of Set 1 : flinders
# Processing Record 9 of Set 1 | mountain home
# Processing Record 10 of Set 1 : mountain home
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 : qaanaaq
# Processing Record 11 of Set 1 | chuy
# Processing Record 12 of Set 1 : chuy
# Processing Record 12 of Set 1 | geraldton
# Processing Record 13 of Set 1 : geraldton
# Processing Record 13 of Set 1 | aklavik
# Processing Record 14 of Set 1 : aklavik
# Processing Record 14 of Set 1 | fortuna
# Processing Record 15 of Set 1 : fortuna
# Processing Record 15 of Set 1 | urusha
# Processing Record 16 of Set 1 : urusha
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 : port alfred
# Processing Record 17 of Set 1 | san-pedro
# Processing Record 18 of Set 1 : san-pedro
# Processing Record 18 of Set 1 | dwarka
# Processing Record 19 of Set 1 : dwarka
# Processing Record 19 of Set 1 | alta floresta
# Processing Record 20 of Set 1 : alta floresta
# Processing Record 20 of Set 1 | saldanha
# Processing Record 21 of Set 1 : saldanha
# Processing Record 21 of Set 1 | askiz
# Processing Record 22 of Set 1 : askiz
# City not found. Skipping...
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 : albany
# Processing Record 23 of Set 1 | tasiilaq
# Processing Record 24 of Set 1 : tasiilaq
# Processing Record 24 of Set 1 | castro
# Processing Record 25 of Set 1 : castro
# Processing Record 25 of Set 1 | new norfolk
# Processing Record 26 of Set 1 : new norfolk
# Processing Record 26 of Set 1 | saint-pierre
# Processing Record 27 of Set 1 : saint-pierre
# Processing Record 27 of Set 1 | airai
# Processing Record 28 of Set 1 : airai
# City not found. Skipping...
# Processing Record 28 of Set 1 | sao felix do xingu
# Processing Record 29 of Set 1 : sao felix do xingu
# Processing Record 29 of Set 1 | nome
# Processing Record 30 of Set 1 : nome
# Processing Record 30 of Set 1 | hilo
# Processing Record 31 of Set 1 : hilo
# Processing Record 31 of Set 1 | victor harbor
# Processing Record 32 of Set 1 : victor harbor
# Processing Record 32 of Set 1 | key largo
# Processing Record 33 of Set 1 : key largo
# Processing Record 33 of Set 1 | alofi
# Processing Record 34 of Set 1 : alofi
# Processing Record 34 of Set 1 | bluff
# Processing Record 35 of Set 1 : bluff
# Processing Record 35 of Set 1 | archidona
# Processing Record 36 of Set 1 : archidona
# Processing Record 36 of Set 1 | alice springs
# Processing Record 37 of Set 1 : alice springs
# Processing Record 37 of Set 1 | vikulovo
# Processing Record 38 of Set 1 : vikulovo
# Processing Record 38 of Set 1 | itarema
# Processing Record 39 of Set 1 : itarema
# City not found. Skipping...
# Processing Record 39 of Set 1 | olinda
# Processing Record 40 of Set 1 : olinda
# Processing Record 40 of Set 1 | atuona
# Processing Record 41 of Set 1 : atuona
# Processing Record 41 of Set 1 | port elizabeth
# Processing Record 42 of Set 1 : port elizabeth
# Processing Record 42 of Set 1 | chokurdakh
# Processing Record 43 of Set 1 : chokurdakh
# Processing Record 43 of Set 1 | provideniya
# Processing Record 44 of Set 1 : provideniya
# Processing Record 44 of Set 1 | khatanga
# Processing Record 45 of Set 1 : khatanga
# Processing Record 45 of Set 1 | ternate
# Processing Record 46 of Set 1 : ternate
# Processing Record 46 of Set 1 | kalach-na-donu
# Processing Record 47 of Set 1 : kalach-na-donu
# Processing Record 0 of Set 2 | los llanos de aridane
# Processing Record 1 of Set 2 : los llanos de aridane
# Processing Record 1 of Set 2 | sulphur springs
# Processing Record 2 of Set 2 : sulphur springs
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 : hobart
# Processing Record 3 of Set 2 | batagay
# Processing Record 4 of Set 2 : batagay
# Processing Record 4 of Set 2 | cody
# Processing Record 5 of Set 2 : cody
# Processing Record 5 of Set 2 | carutapera
# Processing Record 6 of Set 2 : carutapera
# Processing Record 6 of Set 2 | novyy urengoy
# Processing Record 7 of Set 2 : novyy urengoy
# Processing Record 7 of Set 2 | aljezur
# Processing Record 8 of Set 2 : aljezur
# Processing Record 8 of Set 2 | dikson
# Processing Record 9 of Set 2 : dikson
# Processing Record 9 of Set 2 | itoman
# Processing Record 10 of Set 2 : itoman
# Processing Record 10 of Set 2 | avarua
# Processing Record 11 of Set 2 : avarua
# Processing Record 11 of Set 2 | cervo
# Processing Record 12 of Set 2 : cervo
# Processing Record 12 of Set 2 | khuzhir
# Processing Record 13 of Set 2 : khuzhir
# Processing Record 13 of Set 2 | santa vitoria do palmar
# Processing Record 14 of Set 2 : santa vitoria do palmar
# Processing Record 14 of Set 2 | kemijarvi
# Processing Record 15 of Set 2 : kemijarvi
# Processing Record 15 of Set 2 | araure
# Processing Record 16 of Set 2 : araure
# Processing Record 16 of Set 2 | torbay
# Processing Record 17 of Set 2 : torbay
# Processing Record 17 of Set 2 | hwange
# Processing Record 18 of Set 2 : hwange
# Processing Record 18 of Set 2 | svetlogorsk
# Processing Record 19 of Set 2 : svetlogorsk
# Processing Record 19 of Set 2 | ukiah
# Processing Record 20 of Set 2 : ukiah
# Processing Record 20 of Set 2 | upernavik
# Processing Record 21 of Set 2 : upernavik
# Processing Record 21 of Set 2 | nikolskoye
# Processing Record 22 of Set 2 : nikolskoye
# Processing Record 22 of Set 2 | kathu
# Processing Record 23 of Set 2 : kathu
# City not found. Skipping...
# Processing Record 23 of Set 2 | georgetown
# Processing Record 24 of Set 2 : georgetown
# Processing Record 24 of Set 2 | katsuura
# Processing Record 25 of Set 2 : katsuura
# Processing Record 25 of Set 2 | gwembe
# Processing Record 26 of Set 2 : gwembe
# Processing Record 26 of Set 2 | kapaa
# Processing Record 27 of Set 2 : kapaa
# Processing Record 27 of Set 2 | kabalo
# Processing Record 28 of Set 2 : kabalo
# Processing Record 28 of Set 2 | sakakah
# Processing Record 29 of Set 2 : sakakah
# Processing Record 29 of Set 2 | bukachacha
# Processing Record 30 of Set 2 : bukachacha
# Processing Record 30 of Set 2 | maravatio
# Processing Record 31 of Set 2 : maravatio
# Processing Record 31 of Set 2 | bauta
# Processing Record 32 of Set 2 : bauta
# Processing Record 32 of Set 2 | pachmarhi
# Processing Record 33 of Set 2 : pachmarhi
# Processing Record 33 of Set 2 | taltal
# Processing Record 34 of Set 2 : taltal
# Processing Record 34 of Set 2 | orissaare
# Processing Record 35 of Set 2 : orissaare
# Processing Record 35 of Set 2 | mahebourg
# Processing Record 36 of Set 2 : mahebourg
# Processing Record 36 of Set 2 | mafinga
# Processing Record 37 of Set 2 : mafinga
# Processing Record 37 of Set 2 | kitakami
# Processing Record 38 of Set 2 : kitakami
# Processing Record 38 of Set 2 | lavrentiya
# Processing Record 39 of Set 2 : lavrentiya
# Processing Record 39 of Set 2 | ribeira grande
# Processing Record 40 of Set 2 : ribeira grande
# Processing Record 40 of Set 2 | moyale
# Processing Record 41 of Set 2 : moyale
# Processing Record 41 of Set 2 | kieta
# Processing Record 42 of Set 2 : kieta
# City not found. Skipping...
# Processing Record 42 of Set 2 | yukhnov
# Processing Record 43 of Set 2 : yukhnov
# Processing Record 43 of Set 2 | ambilobe
# Processing Record 44 of Set 2 : ambilobe
# Processing Record 44 of Set 2 | montepuez
# Processing Record 45 of Set 2 : montepuez
# Processing Record 45 of Set 2 | saskylakh
# Processing Record 46 of Set 2 : saskylakh
# Processing Record 46 of Set 2 | gornopravdinsk
# Processing Record 47 of Set 2 : gornopravdinsk
# Processing Record 47 of Set 2 | ponta do sol
# Processing Record 48 of Set 2 : ponta do sol
# Processing Record 0 of Set 3 | dauriya
# Processing Record 1 of Set 3 : dauriya
# City not found. Skipping...
# Processing Record 1 of Set 3 | ostrovnoy
# Processing Record 2 of Set 3 : ostrovnoy
# Processing Record 2 of Set 3 | pevek
# Processing Record 3 of Set 3 : pevek
# Processing Record 3 of Set 3 | touros
# Processing Record 4 of Set 3 : touros
# Processing Record 4 of Set 3 | karoi
# Processing Record 5 of Set 3 : karoi
# Processing Record 5 of Set 3 | tokur
# Processing Record 6 of Set 3 : tokur
# Processing Record 6 of Set 3 | sovetskiy
# Processing Record 7 of Set 3 : sovetskiy
# City not found. Skipping...
# Processing Record 7 of Set 3 | casablanca
# Processing Record 8 of Set 3 : casablanca
# Processing Record 8 of Set 3 | narsaq
# Processing Record 9 of Set 3 : narsaq
# Processing Record 9 of Set 3 | longyearbyen
# Processing Record 10 of Set 3 : longyearbyen
# Processing Record 10 of Set 3 | sorland
# Processing Record 11 of Set 3 : sorland
# Processing Record 11 of Set 3 | bambous virieux
# Processing Record 12 of Set 3 : bambous virieux
# Processing Record 12 of Set 3 | tandalti
# Processing Record 13 of Set 3 : tandalti
# Processing Record 13 of Set 3 | lebu
# Processing Record 14 of Set 3 : lebu
# Processing Record 14 of Set 3 | ponta delgada
# Processing Record 15 of Set 3 : ponta delgada
# Processing Record 15 of Set 3 | atar
# Processing Record 16 of Set 3 : atar
# Processing Record 16 of Set 3 | cordoba
# Processing Record 17 of Set 3 : cordoba
# Processing Record 17 of Set 3 | cabo san lucas
# Processing Record 18 of Set 3 : cabo san lucas
# Processing Record 18 of Set 3 | bonavista
# Processing Record 19 of Set 3 : bonavista
# City not found. Skipping...
# Processing Record 19 of Set 3 | khilok
# Processing Record 20 of Set 3 : khilok
# City not found. Skipping...
# Processing Record 20 of Set 3 | aitape
# Processing Record 21 of Set 3 : aitape
# City not found. Skipping...
# Processing Record 21 of Set 3 | codrington
# Processing Record 22 of Set 3 : codrington
# City not found. Skipping...
# Processing Record 22 of Set 3 | kalevala
# Processing Record 23 of Set 3 : kalevala
# Processing Record 23 of Set 3 | tuatapere
# Processing Record 24 of Set 3 : tuatapere
# Processing Record 24 of Set 3 | vila velha
# Processing Record 25 of Set 3 : vila velha
# Processing Record 25 of Set 3 | port moresby
# Processing Record 26 of Set 3 : port moresby
# Processing Record 26 of Set 3 | thompson
# Processing Record 27 of Set 3 : thompson
# Processing Record 27 of Set 3 | birecik
# Processing Record 28 of Set 3 : birecik
# Processing Record 28 of Set 3 | mezen
# Processing Record 29 of Set 3 : mezen
# Processing Record 29 of Set 3 | olafsvik
# Processing Record 30 of Set 3 : olafsvik
# Processing Record 30 of Set 3 | erzin
# Processing Record 31 of Set 3 : erzin
# Processing Record 31 of Set 3 | faanui
# Processing Record 32 of Set 3 : faanui
# Processing Record 32 of Set 3 | cockburn town
# Processing Record 33 of Set 3 : cockburn town
# Processing Record 33 of Set 3 | pak phanang
# Processing Record 34 of Set 3 : pak phanang
# Processing Record 34 of Set 3 | artvin
# Processing Record 35 of Set 3 : artvin
# Processing Record 35 of Set 3 | pangoa
# Processing Record 36 of Set 3 : pangoa
# Processing Record 36 of Set 3 | tynda
# Processing Record 37 of Set 3 : tynda
# Processing Record 37 of Set 3 | kloulklubed
# Processing Record 38 of Set 3 : kloulklubed
# Processing Record 38 of Set 3 | usinsk
# Processing Record 39 of Set 3 : usinsk
# Processing Record 39 of Set 3 | ozernovskiy
# Processing Record 40 of Set 3 : ozernovskiy
# City not found. Skipping...
# Processing Record 40 of Set 3 | tulagi
# Processing Record 41 of Set 3 : tulagi
# Processing Record 41 of Set 3 | moron
# Processing Record 42 of Set 3 : moron
# Processing Record 42 of Set 3 | anadyr
# Processing Record 43 of Set 3 : anadyr
# Processing Record 0 of Set 4 | bayan
# Processing Record 1 of Set 4 : bayan
# Processing Record 1 of Set 4 | tarata
# Processing Record 2 of Set 4 : tarata
# Processing Record 2 of Set 4 | taoudenni
# Processing Record 3 of Set 4 : taoudenni
# Processing Record 3 of Set 4 | palana
# Processing Record 4 of Set 4 : palana
# Processing Record 4 of Set 4 | hambantota
# Processing Record 5 of Set 4 : hambantota
# Processing Record 5 of Set 4 | phetchaburi
# Processing Record 6 of Set 4 : phetchaburi
# Processing Record 6 of Set 4 | svetlyy
# Processing Record 7 of Set 4 : svetlyy
# Processing Record 7 of Set 4 | locri
# Processing Record 8 of Set 4 : locri
# Processing Record 8 of Set 4 | santa maria
# Processing Record 9 of Set 4 : santa maria
# Processing Record 9 of Set 4 | pangai
# Processing Record 10 of Set 4 : pangai
# Processing Record 10 of Set 4 | atakpame
# Processing Record 11 of Set 4 : atakpame
# Processing Record 11 of Set 4 | kautokeino
# Processing Record 12 of Set 4 : kautokeino
# Processing Record 12 of Set 4 | sultanpur
# Processing Record 13 of Set 4 : sultanpur
# City not found. Skipping...
# Processing Record 13 of Set 4 | katherine
# Processing Record 14 of Set 4 : katherine
# Processing Record 14 of Set 4 | champua
# Processing Record 15 of Set 4 : champua
# Processing Record 15 of Set 4 | grindavik
# Processing Record 16 of Set 4 : grindavik
# Processing Record 16 of Set 4 | zambezi
# Processing Record 17 of Set 4 : zambezi
# Processing Record 17 of Set 4 | birao
# Processing Record 18 of Set 4 : birao
# Processing Record 18 of Set 4 | kidal
# Processing Record 19 of Set 4 : kidal
# Processing Record 19 of Set 4 | gorontalo
# Processing Record 20 of Set 4 : gorontalo
# Processing Record 20 of Set 4 | chapais
# Processing Record 21 of Set 4 : chapais
# Processing Record 21 of Set 4 | burnie
# Processing Record 22 of Set 4 : burnie
# Processing Record 22 of Set 4 | vardo
# Processing Record 23 of Set 4 : vardo
# Processing Record 23 of Set 4 | terrak
# Processing Record 24 of Set 4 : terrak
# Processing Record 24 of Set 4 | yulara
# Processing Record 25 of Set 4 : yulara
# Processing Record 25 of Set 4 | ciudad bolivar
# Processing Record 26 of Set 4 : ciudad bolivar
# City not found. Skipping...
# Processing Record 26 of Set 4 | coruripe
# Processing Record 27 of Set 4 : coruripe
# Processing Record 27 of Set 4 | luba
# Processing Record 28 of Set 4 : luba
# Processing Record 28 of Set 4 | matagami
# Processing Record 29 of Set 4 : matagami
# Processing Record 29 of Set 4 | luderitz
# Processing Record 30 of Set 4 : luderitz
# Processing Record 30 of Set 4 | iqaluit
# Processing Record 31 of Set 4 : iqaluit
# City not found. Skipping...
# Processing Record 31 of Set 4 | klaksvik
# Processing Record 32 of Set 4 : klaksvik
# Processing Record 32 of Set 4 | berlevag
# Processing Record 33 of Set 4 : berlevag
# Processing Record 33 of Set 4 | half moon bay
# Processing Record 34 of Set 4 : half moon bay
# Processing Record 34 of Set 4 | poum
# Processing Record 35 of Set 4 : poum
# Processing Record 35 of Set 4 | srednekolymsk
# Processing Record 36 of Set 4 : srednekolymsk
# Processing Record 36 of Set 4 | nantucket
# Processing Record 37 of Set 4 : nantucket
# City not found. Skipping...
# Processing Record 37 of Set 4 | kahului
# Processing Record 38 of Set 4 : kahului
# Processing Record 38 of Set 4 | banjarmasin
# Processing Record 39 of Set 4 : banjarmasin
# Processing Record 39 of Set 4 | jalu
# Processing Record 40 of Set 4 : jalu
# Processing Record 40 of Set 4 | roros
# Processing Record 41 of Set 4 : roros
# Processing Record 41 of Set 4 | goderich
# Processing Record 42 of Set 4 : goderich
# Processing Record 42 of Set 4 | asau
# Processing Record 43 of Set 4 : asau
# Processing Record 43 of Set 4 | san fernando
# Processing Record 44 of Set 4 : san fernando
# Processing Record 44 of Set 4 | talnakh
# Processing Record 45 of Set 4 : talnakh
# Processing Record 45 of Set 4 | ketchikan
# Processing Record 46 of Set 4 : ketchikan
# Processing Record 0 of Set 5 | waynesboro
# Processing Record 1 of Set 5 : waynesboro
# Processing Record 1 of Set 5 | ekhabi
# Processing Record 2 of Set 5 : ekhabi
# Processing Record 2 of Set 5 | port macquarie
# Processing Record 3 of Set 5 : port macquarie
# Processing Record 3 of Set 5 | san patricio
# Processing Record 4 of Set 5 : san patricio
# Processing Record 4 of Set 5 | floro
# Processing Record 5 of Set 5 : floro
# Processing Record 5 of Set 5 | otofuke
# Processing Record 6 of Set 5 : otofuke
# Processing Record 6 of Set 5 | oranjemund
# Processing Record 7 of Set 5 : oranjemund
# Processing Record 7 of Set 5 | pisco
# Processing Record 8 of Set 5 : pisco
# Processing Record 8 of Set 5 | kavieng
# Processing Record 9 of Set 5 : kavieng
# Processing Record 9 of Set 5 | mar del plata
# Processing Record 10 of Set 5 : mar del plata
# Processing Record 10 of Set 5 | pemangkat
# Processing Record 11 of Set 5 : pemangkat
# Processing Record 11 of Set 5 | lisakovsk
# Processing Record 12 of Set 5 : lisakovsk
# Processing Record 12 of Set 5 | manicore
# Processing Record 13 of Set 5 : manicore
# Processing Record 13 of Set 5 | basco
# Processing Record 14 of Set 5 : basco
# Processing Record 14 of Set 5 | aksu
# Processing Record 15 of Set 5 : aksu
# Processing Record 15 of Set 5 | kozan
# Processing Record 16 of Set 5 : kozan
# Processing Record 16 of Set 5 | yellowknife
# Processing Record 17 of Set 5 : yellowknife
# Processing Record 17 of Set 5 | inhambane
# Processing Record 18 of Set 5 : inhambane
# City not found. Skipping...
# Processing Record 18 of Set 5 | havre-saint-pierre
# Processing Record 19 of Set 5 : havre-saint-pierre
# Processing Record 19 of Set 5 | kropotkin
# Processing Record 20 of Set 5 : kropotkin
# Processing Record 20 of Set 5 | matara
# Processing Record 21 of Set 5 : matara
# Processing Record 21 of Set 5 | ciudad guayana
# Processing Record 22 of Set 5 : ciudad guayana
# Processing Record 22 of Set 5 | darhan
# Processing Record 23 of Set 5 : darhan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 23 of Set 5 | okhotsk
# Processing Record 24 of Set 5 : okhotsk
# Processing Record 24 of Set 5 | pemba
# Processing Record 25 of Set 5 : pemba
# Processing Record 25 of Set 5 | kodiak
# Processing Record 26 of Set 5 : kodiak
# Processing Record 26 of Set 5 | nioro
# Processing Record 27 of Set 5 : nioro
# Processing Record 27 of Set 5 | prainha
# Processing Record 28 of Set 5 : prainha
# Processing Record 28 of Set 5 | najran
# Processing Record 29 of Set 5 : najran
# Processing Record 29 of Set 5 | salta
# Processing Record 30 of Set 5 : salta
# Processing Record 30 of Set 5 | naze
# Processing Record 31 of Set 5 : naze
# Processing Record 31 of Set 5 | desaguadero
# Processing Record 32 of Set 5 : desaguadero
# Processing Record 32 of Set 5 | mangan
# Processing Record 33 of Set 5 : mangan
# Processing Record 33 of Set 5 | mumbwa
# Processing Record 34 of Set 5 : mumbwa
# Processing Record 34 of Set 5 | brae
# Processing Record 35 of Set 5 : brae
# Processing Record 35 of Set 5 | havelock
# Processing Record 36 of Set 5 : havelock
# Processing Record 36 of Set 5 | mnogovershinnyy
# Processing Record 37 of Set 5 : mnogovershinnyy
# Processing Record 37 of Set 5 | kiama
# Processing Record 38 of Set 5 : kiama
# Processing Record 38 of Set 5 | port hawkesbury
# Processing Record 39 of Set 5 : port hawkesbury
# Processing Record 39 of Set 5 | bandarbeyla
# Processing Record 40 of Set 5 : bandarbeyla
# Processing Record 40 of Set 5 | sitangkai
# Processing Record 41 of Set 5 : sitangkai
# Processing Record 41 of Set 5 | isangel
# Processing Record 42 of Set 5 : isangel
# Processing Record 42 of Set 5 | yinchuan
# Processing Record 43 of Set 5 : yinchuan
# Processing Record 43 of Set 5 | honiara
# Processing Record 44 of Set 5 : honiara
# Processing Record 44 of Set 5 | salalah
# Processing Record 45 of Set 5 : salalah
# Processing Record 45 of Set 5 | waingapu
# Processing Record 46 of Set 5 : waingapu
# Processing Record 46 of Set 5 | te anau
# Processing Record 47 of Set 5 : te anau
# Processing Record 0 of Set 6 | deputatskiy
# Processing Record 1 of Set 6 : deputatskiy
# Processing Record 1 of Set 6 | tonshayevo
# Processing Record 2 of Set 6 : tonshayevo
# Processing Record 2 of Set 6 | straumen
# Processing Record 3 of Set 6 : straumen
# Processing Record 3 of Set 6 | chulym
# Processing Record 4 of Set 6 : chulym
# Processing Record 4 of Set 6 | pacific grove
# Processing Record 5 of Set 6 : pacific grove
# Processing Record 5 of Set 6 | batemans bay
# Processing Record 6 of Set 6 : batemans bay
# Processing Record 6 of Set 6 | douglas
# Processing Record 7 of Set 6 : douglas
# Processing Record 7 of Set 6 | subkhankulovo
# Processing Record 8 of Set 6 : subkhankulovo
# Processing Record 8 of Set 6 | tamiahua
# Processing Record 9 of Set 6 : tamiahua
# Processing Record 9 of Set 6 | luancheng
# Processing Record 10 of Set 6 : luancheng
# Processing Record 10 of Set 6 | manta
# Processing Record 11 of Set 6 : manta
# Processing Record 11 of Set 6 | nelson bay
# Processing Record 12 of Set 6 : nelson bay
# Processing Record 12 of Set 6 | vanavara
# Processing Record 13 of Set 6 : vanavara
# Processing Record 13 of Set 6 | san quintin
# Processing Record 14 of Set 6 : san quintin
# Processing Record 14 of Set 6 | santarem
# Processing Record 15 of Set 6 : santarem
# Processing Record 15 of Set 6 | mabaruma
# Processing Record 16 of Set 6 : mabaruma
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 16 of Set 6 | leningradskiy
# Processing Record 17 of Set 6 : leningradskiy
# Processing Record 17 of Set 6 | kirs
# Processing Record 18 of Set 6 : kirs
# Processing Record 18 of Set 6 | san angelo
# Processing Record 19 of Set 6 : san angelo
# Processing Record 19 of Set 6 | sayyan
# Processing Record 20 of Set 6 : sayyan
# Processing Record 20 of Set 6 | tiksi
# Processing Record 21 of Set 6 : tiksi
# Processing Record 21 of Set 6 | tromso
# Processing Record 22 of Set 6 : tromso
# Processing Record 22 of Set 6 | guider
# Processing Record 23 of Set 6 : guider
# Processing Record 23 of Set 6 | port lincoln
# Processing Record 24 of Set 6 : port lincoln
# Processing Record 24 of Set 6 | huarmey
# Processing Record 25 of Set 6 : huarmey
# Processing Record 25 of Set 6 | dryden
# Processing Record 26 of Set 6 : dryden
# Processing Record 26 of Set 6 | aykhal
# Processing Record 27 of Set 6 : aykhal
# Processing Record 27 of Set 6 | ascope
# Processing Record 28 of Set 6 : ascope
# Processing Record 28 of Set 6 | severnyy
# Processing Record 29 of Set 6 : severnyy
# Processing Record 29 of Set 6 | thinadhoo
# Processing Record 30 of Set 6 : thinadhoo
# Processing Record 30 of Set 6 | rudbar
# Processing Record 31 of Set 6 : rudbar
# Processing Record 31 of Set 6 | cayenne
# Processing Record 32 of Set 6 : cayenne
# Processing Record 32 of Set 6 | surt
# Processing Record 33 of Set 6 : surt
# Processing Record 33 of Set 6 | erenhot
# Processing Record 34 of Set 6 : erenhot
# Processing Record 34 of Set 6 | chernivtsi
# Processing Record 35 of Set 6 : chernivtsi
# Processing Record 35 of Set 6 | coihaique
# Processing Record 36 of Set 6 : coihaique
# Processing Record 36 of Set 6 | calama
# Processing Record 37 of Set 6 : calama
# Processing Record 37 of Set 6 | riyadh
# Processing Record 38 of Set 6 : riyadh
# Processing Record 38 of Set 6 | sistranda
# Processing Record 39 of Set 6 : sistranda
# Processing Record 39 of Set 6 | abapo
# Processing Record 40 of Set 6 : abapo
# Processing Record 40 of Set 6 | fengzhen
# Processing Record 41 of Set 6 : fengzhen
# Processing Record 41 of Set 6 | nyandoma
# Processing Record 42 of Set 6 : nyandoma
# Processing Record 42 of Set 6 | costinesti
# Processing Record 43 of Set 6 : costinesti
# Processing Record 43 of Set 6 | port hardy
# Processing Record 44 of Set 6 : port hardy
# Processing Record 44 of Set 6 | upington
# Processing Record 45 of Set 6 : upington
# Processing Record 45 of Set 6 | necochea
# Processing Record 46 of Set 6 : necochea
# Processing Record 46 of Set 6 | badou
# Processing Record 47 of Set 6 : badou
# Processing Record 47 of Set 6 | namibe
# Processing Record 48 of Set 6 : namibe
# Processing Record 0 of Set 7 | meulaboh
# Processing Record 1 of Set 7 : meulaboh
# Processing Record 1 of Set 7 | rio gallegos
# Processing Record 2 of Set 7 : rio gallegos
# Processing Record 2 of Set 7 | jalingo
# Processing Record 3 of Set 7 : jalingo
# Processing Record 3 of Set 7 | severo-kurilsk
# Processing Record 4 of Set 7 : severo-kurilsk
# Processing Record 4 of Set 7 | bereda
# Processing Record 5 of Set 7 : bereda
# Processing Record 5 of Set 7 | mishelevka
# Processing Record 6 of Set 7 : mishelevka
# Processing Record 6 of Set 7 | bouar
# Processing Record 7 of Set 7 : bouar
# Processing Record 7 of Set 7 | peleduy
# Processing Record 8 of Set 7 : peleduy
# Processing Record 8 of Set 7 | damara
# Processing Record 9 of Set 7 : damara
# Processing Record 9 of Set 7 | orchard homes
# Processing Record 10 of Set 7 : orchard homes
# Processing Record 10 of Set 7 | gaoua
# Processing Record 11 of Set 7 : gaoua
# Processing Record 11 of Set 7 | beringovskiy
# Processing Record 12 of Set 7 : beringovskiy
# Processing Record 12 of Set 7 | sioux lookout
# Processing Record 13 of Set 7 : sioux lookout
# Processing Record 13 of Set 7 | asilah
# Processing Record 14 of Set 7 : asilah
# City not found. Skipping...
# Processing Record 14 of Set 7 | valparaiso
# Processing Record 15 of Set 7 : valparaiso
# Processing Record 15 of Set 7 | de aar
# Processing Record 16 of Set 7 : de aar
# Processing Record 16 of Set 7 | talas
# Processing Record 17 of Set 7 : talas
# Processing Record 17 of Set 7 | gat
# Processing Record 18 of Set 7 : gat
# Processing Record 18 of Set 7 | pinhao
# Processing Record 19 of Set 7 : pinhao
# Processing Record 19 of Set 7 | constitucion
# Processing Record 20 of Set 7 : constitucion
# Processing Record 20 of Set 7 | redmond
# Processing Record 21 of Set 7 : redmond
# Processing Record 21 of Set 7 | tamandare
# Processing Record 22 of Set 7 : tamandare
# Processing Record 22 of Set 7 | zinder
# Processing Record 23 of Set 7 : zinder
# Processing Record 23 of Set 7 | novikovo
# Processing Record 24 of Set 7 : novikovo
# Processing Record 24 of Set 7 | puerto quijarro
# Processing Record 25 of Set 7 : puerto quijarro
# Processing Record 25 of Set 7 | labuhan
# Processing Record 26 of Set 7 : labuhan
# Processing Record 26 of Set 7 | parana
# Processing Record 27 of Set 7 : parana
# City not found. Skipping...
# Processing Record 27 of Set 7 | omaruru
# Processing Record 28 of Set 7 : omaruru
# Processing Record 28 of Set 7 | lasa
# Processing Record 29 of Set 7 : lasa
# Processing Record 29 of Set 7 | la ronge
# Processing Record 30 of Set 7 : la ronge
# Processing Record 30 of Set 7 | krasnoselkup
# Processing Record 31 of Set 7 : krasnoselkup
# Processing Record 31 of Set 7 | hay river
# Processing Record 32 of Set 7 : hay river
# City not found. Skipping...
# Processing Record 32 of Set 7 | ulladulla
# Processing Record 33 of Set 7 : ulladulla
# City not found. Skipping...
# Processing Record 33 of Set 7 | mkuranga
# Processing Record 34 of Set 7 : mkuranga
# Processing Record 34 of Set 7 | hobyo
# Processing Record 35 of Set 7 : hobyo
# Processing Record 35 of Set 7 | talaya
# Processing Record 36 of Set 7 : talaya
# Processing Record 36 of Set 7 | chardara
# Processing Record 37 of Set 7 : chardara
# Processing Record 37 of Set 7 | arlit
# Processing Record 38 of Set 7 : arlit
# Processing Record 38 of Set 7 | tazovskiy
# Processing Record 39 of Set 7 : tazovskiy
# Processing Record 39 of Set 7 | teguldet
# Processing Record 40 of Set 7 : teguldet
# Processing Record 40 of Set 7 | narasannapeta
# Processing Record 41 of Set 7 : narasannapeta
# Processing Record 41 of Set 7 | rajanpur
# Processing Record 42 of Set 7 : rajanpur
# Processing Record 42 of Set 7 | vila franca do campo
# Processing Record 43 of Set 7 : vila franca do campo
# City not found. Skipping...
# Processing Record 43 of Set 7 | sanandaj
# Processing Record 44 of Set 7 : sanandaj
# Processing Record 44 of Set 7 | caravelas
# Processing Record 45 of Set 7 : caravelas
# Processing Record 0 of Set 8 | sant feliu de guixols
# Processing Record 1 of Set 8 : sant feliu de guixols
# Processing Record 1 of Set 8 | gatton
# Processing Record 2 of Set 8 : gatton
# Processing Record 2 of Set 8 | bardiyah
# Processing Record 3 of Set 8 : bardiyah
# Processing Record 3 of Set 8 | roma
# Processing Record 4 of Set 8 : roma
# Processing Record 4 of Set 8 | altay
# Processing Record 5 of Set 8 : altay
# Processing Record 5 of Set 8 | wuwei
# Processing Record 6 of Set 8 : wuwei
# Processing Record 6 of Set 8 | marystown
# Processing Record 7 of Set 8 : marystown
# Processing Record 7 of Set 8 | husavik
# Processing Record 8 of Set 8 : husavik
# Processing Record 8 of Set 8 | fare
# Processing Record 9 of Set 8 : fare
# Processing Record 9 of Set 8 | syracuse
# Processing Record 10 of Set 8 : syracuse
# Processing Record 10 of Set 8 | mandali
# Processing Record 11 of Set 8 : mandali
# Processing Record 11 of Set 8 | lata
# Processing Record 12 of Set 8 : lata
# Processing Record 12 of Set 8 | praia da vitoria
# Processing Record 13 of Set 8 : praia da vitoria
# Processing Record 13 of Set 8 | fort nelson
# Processing Record 14 of Set 8 : fort nelson
# Processing Record 14 of Set 8 | dingle
# Processing Record 15 of Set 8 : dingle
# Processing Record 15 of Set 8 | paka
# Processing Record 16 of Set 8 : paka
# Processing Record 16 of Set 8 | bulgan
# Processing Record 17 of Set 8 : bulgan
# Processing Record 17 of Set 8 | dahanu
# Processing Record 18 of Set 8 : dahanu
# Processing Record 18 of Set 8 | kangaatsiaq
# Processing Record 19 of Set 8 : kangaatsiaq
# Processing Record 19 of Set 8 | tura
# Processing Record 20 of Set 8 : tura
# Processing Record 20 of Set 8 | vanimo
# Processing Record 21 of Set 8 : vanimo
# Processing Record 21 of Set 8 | mishan
# Processing Record 22 of Set 8 : mishan
# City not found. Skipping...
# Processing Record 22 of Set 8 | ahipara
# Processing Record 23 of Set 8 : ahipara
# Processing Record 23 of Set 8 | leua
# Processing Record 24 of Set 8 : leua
# Processing Record 24 of Set 8 | nichinan
# Processing Record 25 of Set 8 : nichinan
# Processing Record 25 of Set 8 | marsabit
# Processing Record 26 of Set 8 : marsabit
# Processing Record 26 of Set 8 | panguma
# Processing Record 27 of Set 8 : panguma
# Processing Record 27 of Set 8 | komsomolskiy
# Processing Record 28 of Set 8 : komsomolskiy
# Processing Record 28 of Set 8 | banepa
# Processing Record 29 of Set 8 : banepa
# Processing Record 29 of Set 8 | troitsko-pechorsk
# Processing Record 30 of Set 8 : troitsko-pechorsk
# Processing Record 30 of Set 8 | bengkulu
# Processing Record 31 of Set 8 : bengkulu
# Processing Record 31 of Set 8 | purificacion
# Processing Record 32 of Set 8 : purificacion
# Processing Record 32 of Set 8 | nishihara
# Processing Record 33 of Set 8 : nishihara
# Processing Record 33 of Set 8 | belmonte
# Processing Record 34 of Set 8 : belmonte
# Processing Record 34 of Set 8 | the valley
# Processing Record 35 of Set 8 : the valley
# City not found. Skipping...
# Processing Record 35 of Set 8 | santa isabel do rio negro
# Processing Record 36 of Set 8 : santa isabel do rio negro
# Processing Record 36 of Set 8 | esperance
# Processing Record 37 of Set 8 : esperance
# Processing Record 37 of Set 8 | douentza
# Processing Record 38 of Set 8 : douentza
# Processing Record 38 of Set 8 | noumea
# Processing Record 39 of Set 8 : noumea
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 39 of Set 8 | margate
# Processing Record 40 of Set 8 : margate
# Processing Record 40 of Set 8 | tezu
# Processing Record 41 of Set 8 : tezu
# Processing Record 41 of Set 8 | burg
# Processing Record 42 of Set 8 : burg
# Processing Record 42 of Set 8 | sukaraja
# Processing Record 43 of Set 8 : sukaraja
# Processing Record 43 of Set 8 | broome
# Processing Record 44 of Set 8 : broome
# Processing Record 44 of Set 8 | steamboat springs
# Processing Record 45 of Set 8 : steamboat springs
# Processing Record 45 of Set 8 | mocuba
# Processing Record 46 of Set 8 : mocuba
# Processing Record 0 of Set 9 | kathmandu
# Processing Record 1 of Set 9 : kathmandu
# City not found. Skipping...
# Processing Record 1 of Set 9 | gold coast
# Processing Record 2 of Set 9 : gold coast
# Processing Record 2 of Set 9 | telchac
# Processing Record 3 of Set 9 : telchac
# Processing Record 3 of Set 9 | koungheul
# Processing Record 4 of Set 9 : koungheul
# Processing Record 4 of Set 9 | saint-louis
# Processing Record 5 of Set 9 : saint-louis
# Processing Record 5 of Set 9 | trofors
# Processing Record 6 of Set 9 : trofors
# Processing Record 6 of Set 9 | mount isa
# Processing Record 7 of Set 9 : mount isa
# Processing Record 7 of Set 9 | mopti
# Processing Record 8 of Set 9 : mopti
# Processing Record 8 of Set 9 | yeppoon
# Processing Record 9 of Set 9 : yeppoon
# City not found. Skipping...
# Processing Record 9 of Set 9 | banes
# Processing Record 10 of Set 9 : banes
# Processing Record 10 of Set 9 | tessalit
# Processing Record 11 of Set 9 : tessalit
# Processing Record 11 of Set 9 | calvinia
# Processing Record 12 of Set 9 : calvinia
# Processing Record 12 of Set 9 | gallup
# Processing Record 13 of Set 9 : gallup
# City not found. Skipping...
# Processing Record 13 of Set 9 | salsomaggiore terme
# Processing Record 14 of Set 9 : salsomaggiore terme
# Processing Record 14 of Set 9 | eyl
# Processing Record 15 of Set 9 : eyl
# Processing Record 15 of Set 9 | laguna
# Processing Record 16 of Set 9 : laguna
# Processing Record 16 of Set 9 | esmeraldas
# Processing Record 17 of Set 9 : esmeraldas
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 17 of Set 9 | isabela
# Processing Record 18 of Set 9 : isabela
# Processing Record 18 of Set 9 | geilo
# Processing Record 19 of Set 9 : geilo
# Processing Record 19 of Set 9 | beyneu
# Processing Record 20 of Set 9 : beyneu
# Processing Record 20 of Set 9 | dharchula
# Processing Record 21 of Set 9 : dharchula
# Processing Record 21 of Set 9 | vulcan
# Processing Record 22 of Set 9 : vulcan
# Processing Record 22 of Set 9 | portland
# Processing Record 23 of Set 9 : portland
# Processing Record 23 of Set 9 | dumas
# Processing Record 24 of Set 9 : dumas
# Processing Record 24 of Set 9 | rio grande
# Processing Record 25 of Set 9 : rio grande
# Processing Record 25 of Set 9 | hofn
# Processing Record 26 of Set 9 : hofn
# Processing Record 26 of Set 9 | clyde river
# Processing Record 27 of Set 9 : clyde river
# Processing Record 27 of Set 9 | redwater
# Processing Record 28 of Set 9 : redwater
# Processing Record 28 of Set 9 | vydrino
# Processing Record 29 of Set 9 : vydrino
# Processing Record 29 of Set 9 | valledupar
# Processing Record 30 of Set 9 : valledupar
# Processing Record 30 of Set 9 | vila do maio
# Processing Record 31 of Set 9 : vila do maio
# Processing Record 31 of Set 9 | shahreza
# Processing Record 32 of Set 9 : shahreza
# Processing Record 32 of Set 9 | mitu
# Processing Record 33 of Set 9 : mitu
# Processing Record 33 of Set 9 | faya
# Processing Record 34 of Set 9 : faya
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 34 of Set 9 | mount gambier
# Processing Record 35 of Set 9 : mount gambier
# Processing Record 35 of Set 9 | nipawin
# Processing Record 36 of Set 9 : nipawin
# Processing Record 36 of Set 9 | zarubino
# Processing Record 37 of Set 9 : zarubino
# Processing Record 37 of Set 9 | victoria
# Processing Record 38 of Set 9 : victoria
# Processing Record 38 of Set 9 | sladkovo
# Processing Record 39 of Set 9 : sladkovo
# Processing Record 39 of Set 9 | haines junction
# Processing Record 40 of Set 9 : haines junction
# Processing Record 40 of Set 9 | balikpapan
# Processing Record 41 of Set 9 : balikpapan
# Processing Record 41 of Set 9 | spirit river
# Processing Record 42 of Set 9 : spirit river
# Processing Record 42 of Set 9 | aleksandrov gay
# Processing Record 43 of Set 9 : aleksandrov gay
# Processing Record 0 of Set 10 | manokwari
# Processing Record 1 of Set 10 : manokwari
# Processing Record 1 of Set 10 | umea
# Processing Record 2 of Set 10 : umea
# Processing Record 2 of Set 10 | riberalta
# Processing Record 3 of Set 10 : riberalta
# Processing Record 3 of Set 10 | axim
# Processing Record 4 of Set 10 : axim
# Processing Record 4 of Set 10 | la tuque
# Processing Record 5 of Set 10 : la tuque
# Processing Record 5 of Set 10 | aksarka
# Processing Record 6 of Set 10 : aksarka
# Processing Record 6 of Set 10 | bathsheba
# Processing Record 7 of Set 10 : bathsheba
# Processing Record 7 of Set 10 | kutahya
# Processing Record 8 of Set 10 : kutahya
# City not found. Skipping...
# Processing Record 8 of Set 10 | northampton
# Processing Record 9 of Set 10 : northampton
# Processing Record 9 of Set 10 | mazagao
# Processing Record 10 of Set 10 : mazagao
# Processing Record 10 of Set 10 | kupang
# Processing Record 11 of Set 10 : kupang
# Processing Record 11 of Set 10 | zaysan
# Processing Record 12 of Set 10 : zaysan
# Processing Record 12 of Set 10 | shieli
# Processing Record 13 of Set 10 : shieli
# Processing Record 13 of Set 10 | prince rupert
# Processing Record 14 of Set 10 : prince rupert
# Processing Record 14 of Set 10 | luanda
# Processing Record 15 of Set 10 : luanda
# Processing Record 15 of Set 10 | katobu
# Processing Record 16 of Set 10 : katobu
# City not found. Skipping...
# Processing Record 16 of Set 10 | muisne
# Processing Record 17 of Set 10 : muisne
# Processing Record 17 of Set 10 | malbug
# Processing Record 18 of Set 10 : malbug
# City not found. Skipping...
# Processing Record 18 of Set 10 | jonesboro
# Processing Record 19 of Set 10 : jonesboro
# Processing Record 19 of Set 10 | abu samrah
# Processing Record 20 of Set 10 : abu samrah
# City not found. Skipping...
# Processing Record 20 of Set 10 | shirokiy
# Processing Record 21 of Set 10 : shirokiy
# Processing Record 21 of Set 10 | bam
# Processing Record 22 of Set 10 : bam
# Processing Record 22 of Set 10 | skelleftea
# Processing Record 23 of Set 10 : skelleftea
# Processing Record 23 of Set 10 | paita
# Processing Record 24 of Set 10 : paita
# Processing Record 24 of Set 10 | tairua
# Processing Record 25 of Set 10 : tairua
# Processing Record 25 of Set 10 | craig
# Processing Record 26 of Set 10 : craig
# Processing Record 26 of Set 10 | kristiansund
# Processing Record 27 of Set 10 : kristiansund
# Processing Record 27 of Set 10 | hare bay
# Processing Record 28 of Set 10 : hare bay
# Processing Record 28 of Set 10 | grafton
# Processing Record 29 of Set 10 : grafton
# Processing Record 29 of Set 10 | roald
# Processing Record 30 of Set 10 : roald
# Processing Record 30 of Set 10 | padang
# Processing Record 31 of Set 10 : padang
# Processing Record 31 of Set 10 | fairbanks
# Processing Record 32 of Set 10 : fairbanks
# Processing Record 32 of Set 10 | tarakan
# Processing Record 33 of Set 10 : tarakan
# Processing Record 33 of Set 10 | salinas
# Processing Record 34 of Set 10 : salinas
# Processing Record 34 of Set 10 | umtata
# Processing Record 35 of Set 10 : umtata
# Processing Record 35 of Set 10 | ranghulu
# Processing Record 36 of Set 10 : ranghulu
# Processing Record 36 of Set 10 | berkakit
# Processing Record 37 of Set 10 : berkakit
# Processing Record 37 of Set 10 | vuktyl
# Processing Record 38 of Set 10 : vuktyl
# Processing Record 38 of Set 10 | bhubaneswar
# Processing Record 39 of Set 10 : bhubaneswar
# Processing Record 39 of Set 10 | murdochville
# Processing Record 40 of Set 10 : murdochville
# Processing Record 40 of Set 10 | comodoro rivadavia
# Processing Record 41 of Set 10 : comodoro rivadavia
# Processing Record 41 of Set 10 | cozumel
# Processing Record 42 of Set 10 : cozumel
# Processing Record 42 of Set 10 | afua
# Processing Record 43 of Set 10 : afua
# Processing Record 43 of Set 10 | port blair
# Processing Record 44 of Set 10 : port blair
# Processing Record 44 of Set 10 | westport
# Processing Record 45 of Set 10 : westport
# Processing Record 45 of Set 10 | amboasary
# Processing Record 46 of Set 10 : amboasary
# Processing Record 0 of Set 11 | pandan
# Processing Record 1 of Set 11 : pandan
# Processing Record 1 of Set 11 | sarkand
# Processing Record 2 of Set 11 : sarkand
# Processing Record 2 of Set 11 | inverness
# Processing Record 3 of Set 11 : inverness
# Processing Record 3 of Set 11 | keansburg
# Processing Record 4 of Set 11 : keansburg
# Processing Record 4 of Set 11 | fukue
# Processing Record 5 of Set 11 : fukue
# Processing Record 5 of Set 11 | pianoro
# Processing Record 6 of Set 11 : pianoro
# Processing Record 6 of Set 11 | great yarmouth
# Processing Record 7 of Set 11 : great yarmouth
# Processing Record 7 of Set 11 | kavaratti
# Processing Record 8 of Set 11 : kavaratti
# City not found. Skipping...
# Processing Record 8 of Set 11 | rybnoye
# Processing Record 9 of Set 11 : rybnoye
# Processing Record 9 of Set 11 | sobolevo
# Processing Record 10 of Set 11 : sobolevo
# Processing Record 10 of Set 11 | abrego
# Processing Record 11 of Set 11 : abrego
# Processing Record 11 of Set 11 | guiyang
# Processing Record 12 of Set 11 : guiyang
# Processing Record 12 of Set 11 | puro
# Processing Record 13 of Set 11 : puro
# Processing Record 13 of Set 11 | lamu
# Processing Record 14 of Set 11 : lamu
# Processing Record 14 of Set 11 | parker
# Processing Record 15 of Set 11 : parker
# Processing Record 15 of Set 11 | muzhi
# Processing Record 16 of Set 11 : muzhi
# Processing Record 16 of Set 11 | revuca
# Processing Record 17 of Set 11 : revuca
# Processing Record 17 of Set 11 | kitakata
# Processing Record 18 of Set 11 : kitakata
# Processing Record 18 of Set 11 | abu dhabi
# Processing Record 19 of Set 11 : abu dhabi
# City not found. Skipping...
# Processing Record 19 of Set 11 | nova olimpia
# Processing Record 20 of Set 11 : nova olimpia
# Processing Record 20 of Set 11 | acapulco
# Processing Record 21 of Set 11 : acapulco
# Processing Record 21 of Set 11 | baie-comeau
# Processing Record 22 of Set 11 : baie-comeau
# Processing Record 22 of Set 11 | da nang
# Processing Record 23 of Set 11 : da nang
# Processing Record 23 of Set 11 | egvekinot
# Processing Record 24 of Set 11 : egvekinot
# Processing Record 24 of Set 11 | opuwo
# Processing Record 25 of Set 11 : opuwo
# Processing Record 25 of Set 11 | prince george
# Processing Record 26 of Set 11 : prince george
# Processing Record 26 of Set 11 | cidreira
# Processing Record 27 of Set 11 : cidreira
# Processing Record 27 of Set 11 | ardakan
# Processing Record 28 of Set 11 : ardakan
# City not found. Skipping...
# Processing Record 28 of Set 11 | jojoima
# Processing Record 29 of Set 11 : jojoima
# Processing Record 29 of Set 11 | usogorsk
# Processing Record 30 of Set 11 : usogorsk
# Processing Record 30 of Set 11 | yala
# Processing Record 31 of Set 11 : yala
# Processing Record 31 of Set 11 | dillon
# Processing Record 32 of Set 11 : dillon
# Processing Record 32 of Set 11 | jeremoabo
# Processing Record 33 of Set 11 : jeremoabo
# Processing Record 33 of Set 11 | alcacer do sal
# Processing Record 34 of Set 11 : alcacer do sal
# Processing Record 34 of Set 11 | xining
# Processing Record 35 of Set 11 : xining
# City not found. Skipping...
# Processing Record 35 of Set 11 | halifax
# Processing Record 36 of Set 11 : halifax
# City not found. Skipping...
# Processing Record 36 of Set 11 | andenes
# Processing Record 37 of Set 11 : andenes
# Processing Record 37 of Set 11 | lichinga
# Processing Record 38 of Set 11 : lichinga
# Processing Record 38 of Set 11 | ozark
# Processing Record 39 of Set 11 : ozark
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 39 of Set 11 | grand-santi
# Processing Record 40 of Set 11 : grand-santi
# Processing Record 40 of Set 11 | dao
# Processing Record 41 of Set 11 : dao
# Processing Record 41 of Set 11 | dalby
# Processing Record 42 of Set 11 : dalby
# Processing Record 42 of Set 11 | high level
# Processing Record 43 of Set 11 : high level
# Processing Record 0 of Set 12 | khandyga
# Processing Record 1 of Set 12 : khandyga
# Processing Record 1 of Set 12 | saint-francois
# Processing Record 2 of Set 12 : saint-francois
# Processing Record 2 of Set 12 | benguela
# Processing Record 3 of Set 12 : benguela
# Processing Record 3 of Set 12 | nizhniy tsasuchey
# Processing Record 4 of Set 12 : nizhniy tsasuchey
# Processing Record 4 of Set 12 | maple creek
# Processing Record 5 of Set 12 : maple creek
# Processing Record 5 of Set 12 | skibbereen
# Processing Record 6 of Set 12 : skibbereen
# Processing Record 6 of Set 12 | kunda
# Processing Record 7 of Set 12 : kunda
# Processing Record 7 of Set 12 | buala
# Processing Record 8 of Set 12 : buala
# Processing Record 8 of Set 12 | siavonga
# Processing Record 9 of Set 12 : siavonga
# Processing Record 9 of Set 12 | kenai
# Processing Record 10 of Set 12 : kenai
# Processing Record 10 of Set 12 | semey
# Processing Record 11 of Set 12 : semey
# Processing Record 11 of Set 12 | sitka
# Processing Record 12 of Set 12 : sitka
# Processing Record 12 of Set 12 | danjiangkou
# Processing Record 13 of Set 12 : danjiangkou
# Processing Record 13 of Set 12 | tautira
# Processing Record 14 of Set 12 : tautira
# Processing Record 14 of Set 12 | saint anthony
# Processing Record 15 of Set 12 : saint anthony
# Processing Record 15 of Set 12 | hearst
# Processing Record 16 of Set 12 : hearst
# Processing Record 16 of Set 12 | antofagasta
# Processing Record 17 of Set 12 : antofagasta
# Processing Record 17 of Set 12 | marrakesh
# Processing Record 18 of Set 12 : marrakesh
# Processing Record 18 of Set 12 | mirnyy
# Processing Record 19 of Set 12 : mirnyy
# Processing Record 19 of Set 12 | wanning
# Processing Record 20 of Set 12 : wanning
# Processing Record 20 of Set 12 | general roca
# Processing Record 21 of Set 12 : general roca
# Processing Record 21 of Set 12 | bentiu
# Processing Record 22 of Set 12 : bentiu
# Processing Record 22 of Set 12 | manggar
# Processing Record 23 of Set 12 : manggar
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
print (query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=64576b21ada60b2e33b1a026ac523b26&units=imperial&q=

# %%
weather_dict = {
    "City": new_cities,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": dates,
    "Humidity": humidity,
    "Max Temp": max_temp,
    "Lat": lat,
    "Long": long,
    "Wind Speed": wind_speed
}
weather_df = pd.DataFrame(weather_dict)

weather_df.count()
# Out:
# City          571
# Cloudiness    571
# Country       571
# Date          571
# Humidity      571
# Max Temp      571
# Lat           571
# Long          571
# Wind Speed    571
# dtype: int64

# %%
weather_df.head()
# Out:
#            City  Cloudiness Country        Date  Humidity  Max Temp    Lat  \
# 0        barrow          90      US  1607707803        69     -7.60  71.29
# 1       rikitea          75      PF  1607708532        79     76.69 -23.12
# 2    kaitangata          46      NZ  1607707955        73     46.99 -46.28
# 3  punta arenas          75      CL  1607708533        62     55.40 -53.15
# 4        nacala         100      MZ  1607708533        84     79.43 -14.54
#
#      Long  Wind Speed
# 0 -156.79       16.11
# 1 -134.97       13.69
# 2  169.85       10.00
# 3  -70.92       14.99
# 4   40.67        8.28

# %%
weather_df.to_csv("../output_data/cities.csv", index = False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], marker = "o", facecolor = "orange", edgecolor="white")
plt.title("Latitude vs. Temperature (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.grid()
plt.savefig("../Images/LatVsMaxTemp.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Humidity"], marker = "o", facecolor = "blue")
plt.title("City Latitude vs Humidity (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.savefig("../Images/Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], marker = "o", facecolor = "cyan")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs Cloudiness (%s)" % time.strftime("%x"))
plt.grid()
plt.savefig("../Images/LatitudeVsCloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], marker = "o", facecolor = "grey")
plt.xlabel("Latitude")
plt.ylabel("Speed (mph)")
plt.title("City Latitude vs Wind Speed (%s)" % time.strftime("%x"))
plt.grid()
plt.savefig("../Images/LatitudeVsWindSpeed.png")

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
